# %% [markdown]
# # Balance Data
#
# This notebook analysis a data path and determines the number of files in each class. It then uses a predetermined trimming percentage to "trim" the majority class to perform undersampling, by randomly selecting X% of the majority class and deleting the files at those paths.

# %% [markdown]
# ## Imports

# %%
from pathlib import Path
import random
from tqdm.notebook import tqdm

# %% [markdown]
# ## Balance

# %%
p = Path('../data/image_based')

# %%
anomalous = list()
normal = list()
# TODO: add check for directories because we dont want these in the total count 
for i in tqdm(p.glob('**/*')):
    if "train" in str(i):
        if "anomalous" in str(i):
            anomalous.append(i)
        if "normal" in str(i):
            normal.append(i)
# Out:
# |          | 0/? [00:00<?, ?it/s]

# %%
print(len(anomalous), len(normal))
# Out:
# 3785 60367

# %%
len(normal) / len(anomalous)
# Out:
# 15.953068592057761

# %%
len(normal) * .1 # let's try keeping only 10% and removing 90% of the normal data from training?
# Out:
# 61754.100000000006

# %%
(len(normal) *.1) / len(anomalous)
# Out:
# 15.924213512119652

# %%
# randomly sample 90% from the anomalous class to delete
normal_to_delete = random.sample(normal, int(0.9 * len(normal)))
len(normal) - len(normal_to_delete)
# Out:
# 61755

# %%
normal_to_delete[0:2]
# Out:
# [PosixPath('../data/image_based_balanced/hawaii/train/waor__G08/labeled/normal/290_32_92_GAF.jpg'),
#  PosixPath('../data/image_based_balanced/hawaii/train/outl__G20/labeled/normal/291_43_103_GAF.jpg')]

# %%
# delete each of those files 
for i in tqdm(normal_to_delete):
    try:
        Path(i).unlink()
    except IsADirectoryError:
        pass
    except FileNotFoundError:
        print("already deleted")
# Out:
#   0%|          | 0/555786 [00:00<?, ?it/s]
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# ...
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
# already deleted
